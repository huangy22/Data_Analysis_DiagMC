# %%
import IO
import numpy as np
import matplotlib.pyplot as plt
import file_path
import os, matplotlib
import IO
# %matplotlib inline
DOWN, UP=0,1

# %% [markdown]
# ### Cubic Lattice

# %%
def HTE_cubic(beta, order):
    if order >= 8:
        print "Not implemented!"
        return
    
    r = 3.0/4.0  #s(s+1)
    Coeff=np.zeros(8)
    Coeff[0] = r/3
    Coeff[1] = -2*r**2.0/3
    Coeff[2] = 1.0/18*r**2.0*(-3.0+20*r)
    Coeff[3] = -1.0/135*r**2.0*(6.0-91*r+224*r**2.0)
    Coeff[4] = 1.0/1080*r**2.0*(-15.0+376*r-1816*r**2.0+2544*r**3.0)
    Coeff[5] = -1.0/14175*r**2.0*(72.0-2406*r+18909*r**2.0-47188*r**3.0
            +46848.0*r**4.0)
    Coeff[6] = 1.0/2041200*r**2.0*(-4347.0+176346*r-1901709*r**2.0
            +7300134*r**3.0-11982944.0*r**4.0+9482624*r**5.0)
    Coeff[7] = -1.0/61236000*r**2.0*(61560.0-2887056*r+38320749*r**2.0
            -202461642*r**3.0+477409712.0*r**4.0-601876480*r**5.0
            + 399408640*r**6.0)

    Chi = 0.0
    for i in range(order):
        Chi += 3.0*Coeff[i]*(beta)**(i+1.0)
    return Chi

# %%
T_list = np.linspace(0.5, 5.0, 100)
HTE_list = np.zeros((5, len(T_list)))
for t in range(len(T_list)):
    for i in range(4):
        order = i + 4
        HTE_list[i,t] = HTE_cubic(1.0/T_list[t], order)

# %%
plt.figure()
for i in range(4):
    plt.plot(T_list, HTE_list[i], label="Order "+str(i+4))
#y=[0.0937,]*MaxTauBin
#plt.plot(TGrid, y, 'k--', label="Unbiased MC")
plt.ylim([0.0,0.5])
plt.xlim([0.0, 5.1])
plt.xlabel("T/J")
plt.ylabel(r"$\chi(k=0, i\omega_n=0)$")
plt.legend()
plt.title("High-Temperature Expansion")

plt.savefig("cubic_High-Temperature.pdf")
plt.show()

# %%
path_DMC="./cubic/data/DiagMC/"
path_PI="./cubic/data/PathIntegral/"

# %%
BetaList = [0.25, 0.33, 0.5, 1.0, 1.5]

# %%
    #h=1.0
    #Name="L8_H1.0_"
    #OrderList[0.25]=[1, 2, 3, 1000] 
    #OrderList[0.33]=[1, 2, 3, 1000] 
    #OrderList[0.5]=[1, 2, 3, 1000] 
    #OrderList[1.0]=[1, 2, 3, 4, 5, 6, 1000] 

    #h=0.5
    #Name="L8_H0.5_"
    #OrderList[0.25]=[1, 2, 3, 1000] 
    #OrderList[0.33]=[1, 2, 3, 1000] 
    #OrderList[0.5]=[1, 2, 3, 1000] 
    #OrderList[1.0]=[1, 2, 3, 4, 5, 6, 1000] 
    #OrderList[1.5]=[1, 2, 3, 4, 5, 6, 1000] 

    #h=0.25
    #Name="L8_H0.25_"
    #OrderList[0.25]=[1, 2, 3, 1000] 
    #OrderList[0.33]=[1, 2, 3, 1000] 
    #OrderList[0.5]=[1, 2, 3, 1000] 
    #OrderList[1.0]=[1, 2, 3, 4, 5, 6, 1000] 
    #OrderList[1.5]=[1, 2, 3, 1000]

# %%
PI_UnifChi = {}
PI_Err = {}
DMC_UnifChi = {}
DMC_Err = {}

# %%
h=1.0
Name="L8_H1.0_"
OrderList = {}
OrderList[(0.25,h)]=[1, 2, 3] 
OrderList[(0.33,h)]=[1, 2, 3] 
OrderList[(0.5, h)]=[1, 2, 3] 
OrderList[(1.0, h)]=[1, 2, 3, 4, 5, 6] 

for beta in BetaList:
    file="L8_Beta"+str(beta)+"_H"+str(h)+"_ext_hs_sqa0"
    try:
        PI_UnifChi[(beta, h)] = IO.LoadDict(path_PI+file)["UnifChi"]["value"]
        PI_Err[(beta, h)] = IO.LoadDict(path_PI+file)["UnifChi"]["error"]
    except:
        continue
    
    DMC_UnifChi[(beta,h)] = []
    DMC_Err[(beta,h)] = []
    if (beta, h) in OrderList:
        for order in OrderList[(beta, h)]:
            file="L8_Beta"+str(beta)+"_H"+str(h)+"_Order"+str(order)+"_Dyson_Err"

            try:
                DMC_UnifChi[(beta, h)].append(IO.LoadDict(path_DMC+file)["UnifChi"]["value"].real)
                DMC_Err[(beta, h)].append(IO.LoadDict(path_DMC+file)["UnifChi"]["error"].real)
            except:
                continue

# %%
h=0.5
Name="L8_H0.5_"
OrderList = {}
OrderList[(0.25,h)]=[1, 2, 3] 
OrderList[(0.33,h)]=[1, 2, 3] 
OrderList[(0.5, h)]=[1, 2, 3] 
OrderList[(1.0, h)]=[1, 2, 3, 4, 5, 6] 
OrderList[(1.5, h)]=[1, 2, 3, 4, 5, 6] 

for beta in BetaList:
    file="L8_Beta"+str(beta)+"_H"+str(h)+"_ext_hs_sqa0"
    try:
        PI_UnifChi[(beta, h)] = IO.LoadDict(path_PI+file)["UnifChi"]["value"]
        PI_Err[(beta, h)] = IO.LoadDict(path_PI+file)["UnifChi"]["error"]
    except:
        continue
        
    DMC_UnifChi[(beta,h)] = []
    DMC_Err[(beta,h)] = []
    for order in OrderList[(beta, h)]:
        file="L8_Beta"+str(beta)+"_H"+str(h)+"_Order"+str(order)+"_Dyson_Err"

        try:
            DMC_UnifChi[(beta, h)].append(IO.LoadDict(path_DMC+file)["UnifChi"]["value"].real)
            DMC_Err[(beta, h)].append(IO.LoadDict(path_DMC+file)["UnifChi"]["error"].real)
        except:
            continue

# %%
DMC_UnifChi
# Out:
# {(0.25, 1.0): [0.04338704877217178, 0.04361752373129897, 0.04328746801208011],
#  (0.33, 1.0): [0.051352213501197404,
#   0.051744067486763995,
#   0.05111129505268552],
#  (0.5, 1.0): [0.0624492422387642, 0.06326421951770236, 0.06149764567593978],
#  (1.0, 1.0): [0.035981390914040484,
#   0.039124361386605924,
#   0.035764510526665,
#   0.035300523507843365,
#   0.03518867077626288,
#   0.03502766751378188]}

# %%
beta=1.0
plt.figure()
plt.errorbar(1.0/np.array(OrderList[(beta, h)]), DMC_UnifChi[(beta, h)], yerr=DMC_Err[(beta,h)], label="DiagMC",fmt='o-')
y=np.array([PI_UnifChi[(beta,h)]]*2)
yerr=np.array([PI_Err[(beta,h)]]*2)
plt.errorbar([0.0, 1.0], y+yerr, c='k', label="Unbiased MC")
plt.errorbar([0.0, 1.0], y-yerr, c='k')
#plt.ylim([0.24, 0.39])
plt.xlim([0,1])
plt.xlabel("1/Order")
plt.ylabel(r"$\chi(k=0, i\omega_n=0)$")
plt.title(r"Convergence at $\beta J = 1.0$, $h=1.0$")
plt.legend()

plt.savefig("cubic_Convergence_Beta1_h1.pdf")
plt.show()

# %%
beta=0.5
plt.figure()
plt.errorbar(1.0/np.array(OrderList[(beta, h)]), DMC_UnifChi[(beta, h)], yerr=DMC_Err[(beta,h)], label="DiagMC",fmt='o-')
y=np.array([PI_UnifChi[(beta,h)]]*2)
yerr=np.array([PI_Err[(beta,h)]]*2)
plt.errorbar([0.0, 1.0], y+yerr, c='k', label="Unbiased MC")
plt.errorbar([0.0, 1.0], y-yerr, c='k')
#plt.ylim([0.24, 0.39])
plt.xlim([0,1])
plt.xlabel("1/Order")
plt.ylabel(r"$\chi(k=0, i\omega_n=0)$")
plt.title(r"Convergence at $\beta J = 0.5$, $h=1.0$")
plt.legend()

plt.savefig("cubic_Convergence_Beta0.5_h1.pdf")
plt.show()

# %%
beta=1.0
h=0.5
plt.figure()
plt.errorbar(1.0/np.array(OrderList[(beta, h)]), DMC_UnifChi[(beta, h)], yerr=DMC_Err[(beta,h)], label="DiagMC",fmt='o-')
y=np.array([PI_UnifChi[(beta,h)]]*2)
yerr=np.array([PI_Err[(beta,h)]]*2)
plt.errorbar([0.0, 1.0], y+yerr, c='k', label="Unbiased MC")
plt.errorbar([0.0, 1.0], y-yerr, c='k')
#plt.ylim([0.24, 0.39])
plt.xlim([0,1])
plt.xlabel("1/Order")
plt.ylabel(r"$\chi(k=0, i\omega_n=0)$")
plt.title(r"Convergence at $\beta J = 1$, $h=0.5$")
plt.legend()

plt.savefig("cubic_Convergence_Beta1_h0.5.pdf")
plt.show()
